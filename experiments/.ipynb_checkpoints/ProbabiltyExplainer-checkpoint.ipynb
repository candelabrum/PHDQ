# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import pickle
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import networkx as nx
import scipy.stats as ss
import pandas as pd
import numpy as np

from IPython.display import HTML, display_html
from phd_qwen_CUDA_clean import get_phd, load_roberta_model, load_qwen_model, get_embeds, preprocess_text
from lexicalrichness import LexicalRichness
from collections import Counter, defaultdict
from tqdm import tqdm
from phd_scale import set_all_seeds, load_qwen_model, get_embeds, get_answer,\
                      get_stats, get_embeds_tsne, get_mst_edge_lengths, calculate_df_edges, visualize_text
from phd_qwen_CUDA_clean import preprocess_text, pairwise_distances


set_all_seeds(42)
sns.set_style("darkgrid")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def get_len_tokens(tokenizer, text):
    return len(tokenizer.tokenize(text))


token = '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'
tokenizer, model = load_qwen_model("google/gemma-2-2b-it", device='cuda:2', token=token)
df_en = pd.read_json("../PHD_experiments/notebooks/PHD_another/data/dev_intrinc_dimensions_roberta_gemma_qwen_phd__mle_twonn_tle.json")
df_en['gemini_tokenizer_len'] = df_en['text'].apply(lambda x: get_len_tokens(tokenizer, preprocess_text(x)))
text = df_en['text'].values.tolist()[1]
texts = df_en['text'].values.tolist()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Модель загружена на: cuda:2

# %%
from collections import defaultdict, Counter


def get_prompt(
    text,
    tokenizer,
    model,
    limit=None
):
    if limit:
        text = ''.join(tokenizer.tokenize(text)[:limit]).replace('▁', ' ')
    embeds, tokens = get_embeds_tsne(text, tokenizer, model, returns_tokenized=True, reducer_type='none')
    mst_lengths = get_mst_edge_lengths(embeds, return_matrix=True)
    df_edges = calculate_df_edges(tokens, mst_lengths)
    df_edges['quantile'] = (pd.qcut(df_edges['weight'], q=99).rank(pct=True) * 100).apply(int)

    return df_edges, tokens


def draw_html(tokens_and_weights, cmap=plt.get_cmap("bwr"), display=True,
              token_template="""<span style="background-color: {color_hex}">{token}</span>""",
              font_style="font-size:14px;"
             ):
    
    def get_color_hex(weight):
        rgba = cmap(1. / (1 + np.exp(float(weight))), bytes=True)
#        rgba = cmap(float(weight), bytes=True)
        return '#%02X%02X%02X' % rgba[:3]
    
    tokens_html = [
        token_template.format(token=token, color_hex=get_color_hex(weight))
        for token, weight in tokens_and_weights
    ]
    
    
    raw_html = """<p style="{}">{}</p>""".format(font_style, ' '.join(tokens_html))
    if display:
        display_html(HTML(raw_html))
        
    return raw_html


def visualize_text(text, tokenizer, model, display=True):
    df_edges, tokens = get_prompt(text, tokenizer, model)
    df_row = df_edges.groupby('row')[['weight', 'quantile']].mean()
    df_col = df_edges.groupby('col')[['weight', 'quantile']].mean()
    df_concat = pd.concat([df_row, df_col]).reset_index()
    df_mean = df_concat.groupby('index').mean()
    tokens_and_weights = list(zip(tokens, (df_mean['quantile'].values.tolist() - df_mean['quantile'].median()) / 100))
    draw_html(tokens_and_weights, display=display)
    df_mean['token'] = tokens

    return df_mean


def get_repets(tokens):
    repets = []
    cnt = Counter()
    for token in tokens:
        cnt[token] += 1
        repets.append(cnt[token])

    return repets


def get_high_and_low_parts(df_mean):
    high_parts = []
    low_parts = []
    is_high_part = True
    begin = 0
    end = 0
    for row_idx, row in df_mean.iterrows():
    #    print(row['token'])
        if row['quantile'] > 75 and is_high_part:
            pass
    #        print("is high part continued")
        elif row['quantile'] < 25 and is_high_part or df_mean.shape[0] == end + 1:
            is_high_part = False
            high_parts.append(''.join(df_mean.iloc[begin:(end), :]['token']))
            begin = end
    #        print("high_part ended")
        elif row['quantile'] > 75 and not is_high_part:
            is_high_part = True
            low_parts.append(''.join(df_mean.iloc[begin:(end), :]['token']))
            begin = end
        elif row['quantile'] < 25 and not is_high_part:
            pass
        else:
            pass
        end += 1

    return low_parts, high_parts

# %%
from scipy.special import softmax



def get_dot_index(dot_indices, x):
    return  x - np.array(dot_indices)[np.argmin((x - np.array(dot_indices))[x - np.array(dot_indices) >= 0])]
    

def show_prob(text, tokenizer, model):
    embeds, tokens = get_embeds(text, tokenizer, model, returns_tokenized=True, last_hidden_state=None)
    tokens_ids = [tokenizer.encode(token)[1] for token in tokens]
    assert len(tokens_ids) == embeds.shape[0], f"len(tokens_ids) = {len(tokens_ids)}, embeds.shape[0] = {embeds.shape[0]}"
    probs = []
    for i in range(len(tokens_ids) - 1):
        prob = softmax(embeds[i, :])[tokens_ids[i + 1]]
        probs.append(prob)

    return probs
    

## строим классификатор и удаляем из текстов повторяющиеся токены. Смотрим что получается.



df_means = []
punct = ['.', ',', '?', '!', '(', '"', ')']
for text in tqdm(np.array(texts)[np.random.choice(len(texts), size=500)]):
    df_mean = visualize_text(text, tokenizer, model, False)
    df_mean['len_text'] = df_mean.shape[0]
    df_mean = df_mean.reset_index()
    df_mean['prob'] = [1.0] + show_prob(text, tokenizer, model)
    dot_indices = [-1] + [idx for idx, token in enumerate(df_mean['token'].values.tolist()) if token in punct] + [df_mean.shape[0]]
    df_mean['dot_distance'] = df_mean['index'].apply(
        lambda x: get_dot_index(dot_indices, x) 
    )
    df_mean = df_mean.set_index('index')
    df_means.append(df_mean)
# for df_mean in df_means:
#     df_mean['freq_token'] = df_mean['token'].apply(lambda x: cnt[x])
# Out:
# 100%|██████████| 500/500 [05:42<00:00,  1.46it/s]

# %%
import nltk
from nltk import pos_tag, ne_chunk


low_parts_list = []
high_parts_list = []
for df_mean in tqdm(df_means):
    low_parts, high_parts = get_high_and_low_parts(df_mean)
    low_parts_list.extend(low_parts)
    high_parts_list.extend(high_parts)
# Out:
# 100%|██████████| 500/500 [00:09<00:00, 53.77it/s]

# %%
import pickle


with open("data/idf.pickle", "rb") as fd:
    idf = pickle.load(fd)


count_cap_letters = lambda low_part: len(set(low_part) - set(low_part.lower()))

# %%
def get_idf(texts):
    idf = Counter()
    sum_len = 0
    for text in tqdm(texts):
        tokens = list(set([tokenizer.decode([tok]) for tok in tokenizer(text)['input_ids']]))
        idf.update(tokens)
    for key, value in idf.items():
        idf[key] = np.log(1 + len(texts) / idf[key])

    return idf


def calculate_specific_phrases(high_parts_list):
    pos_tags = []
    pos_tag_high = list()
    cap_latters_high = list()
    ne_high = list()
    
    idf_highs = []
    for high_part in tqdm(high_parts_list):
        tokens = list(set([tokenizer.decode([tok]) for tok in tokenizer(high_part)['input_ids']]))[1:]
        if len(tokens) > 0:
            idf_parts = []
            for token in tokens:
                idf_parts.append(idf[token])
            pos_tag_high.extend(pos_tag([token.replace(' ', '') for token in tokens]))
            idf_part = np.max(idf_parts)
            idf_highs.append(idf_part)
            cap_latters_high.append(count_cap_letters(high_part))
    #        ne_high.extend([elem[1] for elem in ne_chunk(pos_tag([token.replace(' ', '') for token in tokens])).pos()])
        else:
            continue

    return pos_tag_high, cap_latters_high, idf_highs

# %%
def normalize_cnt(cnt):
    sum_cnt = sum(cnt.values())
    
    for key, value in cnt.items():
        cnt[key] /= sum_cnt

    return cnt

# %%
pos_tag_high, cap_latters_high, idf_highs = calculate_specific_phrases(high_parts_list)
pos_tag_low, cap_latters_low, idf_low = calculate_specific_phrases(low_parts_list)

cnt_low = Counter([elem[1] for elem in pos_tag_low])
cnt_high = Counter([elem[1] for elem in pos_tag_high])

sum_cnt_low = sum(cnt_low.values())
sum_cnt_high = sum(cnt_high.values())

cnt_low = normalize_cnt(cnt_low)
cnt_high = normalize_cnt(cnt_high)
# Out:
# ...
# 100%|██████████| 10300/10300 [00:04<00:00, 2459.12it/s]

# %%
data['prob_decile'] = data['prob'].apply(lambda x: np.round(x, 2))

# %%
data.groupby('prob_decile')[['quantile']].mean().plot()
# Out:
# <Axes: xlabel='prob_decile'>

# %%
df_tags = pd.DataFrame([elem for elem in pos_tag_high if elem[1] in ['.', 'NNP', ':', 'PRP']], columns=['pos', 'tag'])

# %%
all_high_tokens = data.query("quantile > 90").shape[0]

# %%
all_high_surprise_tokens = data.query("quantile > 90 and prob < 0.001").shape[0]

# %%
all_low_surprise_tokens = data.query("quantile < 10 and prob < 0.001").shape[0]

# %%
all_surprise_tokens = data.query(" prob < 0.001").shape[0]

# %%
all_high_tokens
# Out:
# 14280

# %%
all_surprise_tokens
# Out:
# 11904

# %%
all_high_surprise_tokens
# Out:
# 2973

# %%
all_low_surprise_tokens
# Out:
# 257

# %%
data
# Out:
#      index       token      weight  quantile  len_text          prob  \
# 0        0       <bos>  131.056305      97.0       495  1.000000e+00
# 1        1         The   90.983406      93.0       495  9.988452e-02
# 2        2       intra  163.225922      99.0       495  4.272870e-08
# 3        3     cluster   98.643120      95.0       495  1.272106e-03
# 4        4      medium   84.078686      89.0       495  1.985893e-01
# ..     ...         ...         ...       ...       ...           ...
# 112    112         and   65.285759      57.0       117  1.480061e-01
# 113    113   Universal  127.943039      96.0       117  3.033844e-02
# 114    114     Studios  130.775978      97.0       117  9.821732e-01
# 115    115       Japan   97.509718      72.0       117  9.962126e-01
# 116    116           .   19.965645       1.0       117  9.747742e-01
#
#      dot_distance  count  repet  index_quantile       idf     tfidf  \
# 0               1      1      1               0  0.693147  0.000069
# ...

# %%
data_filter = data.query("prob < 0.001 ")

# %%
plt.scatter(data_filter['quantile'], data_filter['prob'], alpha=0.01)

# %%
plt.scatter(data_filter.query("quantile < 20")['idf'].clip(0, 10), data_filter.query("quantile < 20")['prob'], alpha=0.1)

# %%
plt.scatter(data_filter.query("quantile > 80")['idf'].clip(0, 10), data_filter.query("quantile > 80")['prob'], alpha=0.01)

# %%
data_filter['idf'].hist()
# Out:
# <Axes: >

# %%
data.query("prob < 0.001 ")['quantile'].hist()
plt.title("prob < 0.001 distribution of quantile")
# Out:
# Text(0.5, 1.0, 'prob < 0.001 distribution of quantile')

# %%
# Out:
# <Axes: >

# %%
data.query("quantile < 99 and token != '<bos>'")['prob'].hist()
# Out:
# <Axes: >

# %%
df_tags.query("tag == '.'").value_counts()
# Out:
# pos  tag
# .    .      1413
# ?    .        52
# !    .        44
# Name: count, dtype: int64

# %%
df_tags.query("tag == ':'").value_counts()
# Out:
# pos  tag
# -    :      798
# :    :      192
# ;    :       34
# ...  :       32
# --   :       17
# Name: count, dtype: int64

# %%
df_tags.query("tag == 'PRP'").value_counts()
# Out:
# pos         tag
# you         PRP    434
# it          PRP    405
# I           PRP    300
# they        PRP    158
# we          PRP    117
# It          PRP     87
# me          PRP     74
# he          PRP     68
# them        PRP     51
# You         PRP     50
# him         PRP     48
# us          PRP     43
# We          PRP     37
# she         PRP     33
# They        PRP     26
# <bos>       PRP     15
# yourself    PRP     14
# themselves  PRP      9
# He          PRP      8
# itself      PRP      7
# myself      PRP      5
# s           PRP      4
# She         PRP      3
# her         PRP      3
# self        PRP      2
# US          PRP      2
# himself     PRP      2
# "           PRP      1
#             PRP      1
# herself     PRP      1
# mm          PRP      1
# osen        PRP      1
# oe          PRP      1
# ourselves   PRP      1
# okay        PRP      1
# ophy        PRP      1
# Name: count, dtype: int64

# %%
df_low = pd.DataFrame(cnt_low.items(), columns=['pos', 'freq_low']).set_index('pos')
df_high = pd.DataFrame(cnt_high.items(), columns=['pos', 'freq_high']).set_index('pos')
df_joined = df_low.join(df_high)
df_joined = df_joined.sort_values('freq_low', ascending=False)

# %%
from statsmodels.stats.proportion import proportions_ztest


df_joined['pvalue'] = df_joined.apply(
    lambda x: proportions_ztest([x['freq_low'] * sum_cnt_low, x['freq_high'] * sum_cnt_high], [sum_cnt_low, sum_cnt_high])[1],
    axis=1
)

# %%
low_part_string = """| Sentence / Fragment | Classification |
| :--- | :--- |
| and low . | Other |
| Our motivation stems from the scarcity of known Jupiter the mechanisms governing their formation and migration . | Main |
| We employ a combination of precise measurements , spectroscopy, and analysis to identify five . | Main |
| Our methodology consists of applying a hybrid approach, combining modeling with to filter out . | Main |
| We obtain accurate masses parameters for the detected planets, which we find to occupy a unique region of Our results provide valuable insights into the intermediate , offering opportunities to test theories of planet formation and migration. | Main |
| The discovered planets will serve as prime targets for future ) in the Labour Party. | Main |
| Education Joseph Glu January 1895 . | Other |
| He was the youngest of seven children, born . | Main |
| Links was educated at the later attended the . | Main |
| Career Links started his career in politics during 22, he was elected as of . | Main |
| Links served as . | Main |
| During his parliamentary career, Links was known for his advocacy on issues related to workers' rights, and education. | Main |
| After leaving politics, Links returned to his textile industry. | Main |
| He was also involved in various charitable organizations and initiatives. | Main |
| Life Joseph Gluckstein Links together. | Other |
| He died on 20 November 64, 9. | Main |
| Legacy Joseph Gluckstein Links his dedication to the Labour Party and his commitment to improving the lives of working . | Other |
| His contributions to the textile industry and charitable sector have also . | Main |
| In recognition of his service to the Labour Party, Links was 54. | Main |
| References Joseph Gluckstein Links', 7. | Other |
| * 'Joseph Gluckstein Links', The Reporter, Volume 134, 1955. | Other |
| Columbia was often used. | Main |
| The word premier is derived from the the premier is the day lieutenant governor). | Main |
| government in British Columbia is said to be . | Main |
| The position of premier is not described in . , the leader usually invited by the lieutenant governor to responsibilities | Main |
| The responsibilities of the premier usually include: recommending ministers to the Lieutenant Governor serving as the of the Executive Council and head of the provincial Cabinet. | Main |
| leading the development policies and priorities serving as the priorities and plans between: the Lieutenant Governor and Cabinet the British Columbia government and other provincial and territorial governments the British Columbia Government and the government and international governments | Subordinate |
| the premier selects ministers the Lieutenant Governor. | Main |
| Cabinet government ministries; they are responsible for the government ministries such for proposing new laws or changing existing ones. | Main |
| The premier may also choose an individual who is not an MLA to be a minister, although , the practice is that the minister . | Main |
| The appointment of an MLA to Cabinet is based on their ability and expertise and is also influenced by such as and ethnicity. | Main |
| A minister remains in office solely at the premier. | Main |
| The resignation of the premier the other members of Cabinet. | Main |
| by the Welsh Rugby Union and by the four regions. | Subordinate |
| The Welsh players they want to keep or release. | Subordinate |
| "We appreciate that this is a difficult time for the players involved and families, and we will support them in every way possible." | Main |
| "The Ospreys would like to place players for their contribution to the region over The players Ospreys are , Dan , , , Jarvis, , Dan Baker, , Dan Baker, Tom field, ham, is the implementation of emotion reading of student emotional responses, providing valuable insights that can inform teaching strategies reading technology analyzes to interpret decode emotional cues unlocks a in the classroom. | Main |
| By identifying positive engagement can tailor their instruction to evoke curiosity, stimulate interest, and foster a . | Subordinate |
| Conversely, identifying or distress allows teachers to intervene proactively by their explanations. | Main |
| Furthermore, emotion reading technology can revolutionize the learning process by facilitating personalized feedback . | Main |
| By providing immediate feedback on emotional responses to quizzes, tests, or presentations, students can gain valuable insights into their strengths . | Main |
| This allows students to . | Main |
| Additionally, the technology can personalize activities that align with their emotional engagement levels. | Main |
| Beyond simply enhancing engagement, emotion reading technology also holds immense potential to By identifying emotional triggers emotional responses to various teaching strategies, educators can tailor their approaches to better . | Main |
| This approach can foster a more equitable and accessible learning environment for all students. | Main |
| However implementing emotion reading technology effectively requires consideration and and . | Main |
| Additionally interpret and apply the data collected from the technology ethically of emotion reading By providing deeper insights into student emotional states, this innovative solution can empower educators to tailor their teaching strategies, personalize the learning experience, and ultimately foster deeper understanding and represented and processed incomplete fully express their meaning, and thus not provide a precise, unambiguous representation of the constraint problem . | Subordinate |
| The solution characterizes data sets and row or column relationship its values. | Main |
| For example, it may ask the user how many rows can from a particular table before displaying all rows associated with other tables. | Main |
| This new feature enables users to achieve higher resolution than possible using tools available today, such . | Main |
| In addition, grasses and scattered trees. | Other |
| Savannas are found they typically have a season and a . | Main |
| Savannas are home ivores such as bras, and ffes. | Main |
| Savannas are and just like an individual person reason that corporations may be treated as legal persons is to make it easier for them to do business and interact system. | Main |
| For the individual shareholders ) of the corporation efficient and practical for corporations to engage in business activities n n reason that corporations may be treated as legal persons is to them accountable for their actions. | Subordinate |
| If a corporation engages . | Subordinate |
| This helps to ensure that responsibility for their actions and n as legal persons allows them to easily participate in commerce scientists discovered natural could also be proven that face that was found was found has because It could have been that with it look like a human face. | Main |
| It could of just simply have been a coincidence that it happened like that. | Main |
| way we could say that maybe it was an alien or just a natural landform, because . | Main |
| The human being the human being is incorrect because they prove that what they said was correct. | Main |
| in $S$ below a given value $x$ $) and the $ th smallest element in $S$ can be determined in | Subordinate |
| We present a data structure which uses only ) + $O(\lg \lg m)$ bits to store a set of size $n$, and that can answer these operations in | Main |
| The $\Delta G^*$ value obtained by this method is compared with that determined by other methods such as chemistry. | Main |
"""

high_part_string = """| Sentence / Fragment | Classification |
| :--- | :--- |
| `<bos>We report the discovery of five intermediate-period planets from the N2K sample...` | Main |
| `stellar jitter -type planets in the 10-100 day period range, where remain poorly understood` | Other |
| `radial velocity from the Keck and Magellan telescopes high-resolution stellar activity planet-hosting stars` | Other |
| `Bayesian Keplerian orbital machine learning algorithms false positives planetary and orbital parameter space featuring low eccentricities and masses between 0.3-3 times that of Jupiter.` | Other |
| `-period planet population atmospheric characterization studies , enabling a deeper understanding of their formation and evolution` | Subordinate |
| `<bos>Joseph Gluckstein Links was a British businessman, politician and Member of Parliament (MP)` | Main |
| `Early Life and ckstein Links was born on 14 in Kings Lynn, Norfolk, England to a Jewish family` | Main |
| `local state school in Kings Lynn and University of Cambridge, where he studied economics` | Other |
| `World War I, when he was a member of the Labour Party's executive committee.` | Subordinate |
| `In 19 a Labour MP for the constituency Cambridgeshire an MP for 14 years, before losing his seat in the 1935 general election unemployment, business interests and became a leading figure in the social welfare` | Subordinate |
| `Personal married Beatrice Ellen (née Grad) in 1920, and they had three children 19 at the age of 6 is remembered for -class people been recognized awarded the Order of the British Empire (OBE) in 19 * '` | Other |
| `Who Was Who, Oxford University Press, 200 Cambridge University` | Other |
| `Labour History Review, Volume 2 -2 200 1` | Other |
| `<bos>The premier of British Columbia is the first minister and head of government for the Canadian province of` | Main |
| `Until the early 1970s, the title prime minister of British French word of the same spelling, meaning "first"; and ultimately from the Latin word primarius, meaning "primary".` | Main |
| `Legal status Although -to-day leader of the provincial government, they receive the authority to govern from the Crown...` | Subordinate |
| `Formally, the executive branch of vested in the lieutenant governor acting by and with the advice and consent of the executive council Canadian constitutional statutes` | Subordinate |
| `By convention of the political party that has the support of a majority of members of the Legislative Assembly is form the government.` | Subordinate |
| `Formal the appointment and dismissal of president and implementation of government senior communicator of government federal President of the Executive Council Generally, MLAs from their party to be appointed of the Crown by appointees are designated ministers in charge of day-to-day activities of individual as the Ministry of Forests, and cabinet on the rare occasion that this does happen proceeds to obtain a seat in the House political considerations geography, gender the pleasure of also triggers the resignation of See also Prime Minister of Canada Premier (Canada List of premiers of External links Premier Official Legislative Assembly of British` | Other |
| `<bos>The players, who each represent one of the four Welsh regions, have 1 Wales caps between them.` | Main |
| `Dual contracts are funded 60 40 Rugby Union also confirmed that the Ospreys have not been given the option of choosing the Ospre Operations Manager Andrew Millward said: their on record our thanks to the the years."` | Main |
| `set to leave the Alun Wyn Jones, Ashley Beck Biggar, Joe Bearman James King Aaron Jeff Hassler Ben John Habber Tom Grab Joe Rees and Kristian Phillips` | Other |
| `<bos>## Enhancing Engagement and Learning: The Potential of Emotion Reading Technology in the Classroom` | Other |
| `The contemporary educational landscape demands innovative solutions to foster deeper student engagement and enhance comprehension of schoolwork.` | Main |
| `One promising avenue to explore technology in the classroom.` | Main |
| `This technology offers a nuanced understanding and optimize learning outcomes.` | Main |
| `Emotion facial expressions, vocal intonation, and body language students' emotional states.` | Other |
| `This ability to wealth of potential applications , teachers sense of connection with the material moments of confusion providing additional support or adjusting and promoting intrinsic motivation and weaknesses data-driven approach self-regulate their emotions, focus better, and stay motivated learning pathways by recommending resources and support diverse learners.` | Subordinate |
| `Students with dyslexia or attention deficit hyperactivity disorder (ADHD) often struggle with traditional learning methods.` | Main |
| `and cater to these unique needs inclusive , careful ethical considerations.` | Other |
| `Privacy concerns regarding student data must be addressed through robust security measures clear data protection protocols , teachers must be trained to and responsibly.` | Main |
| `In conclusion, the potential technology to revolutionize student engagement and learning is undeniable.` | Main |
| `academic success` | Other |
| `Much of the mass in a halo of $10^{14} M_{\text{sun}}$ comes in through accretion of $\sim 10^{13} M_{\text{sun}}$ halos.` | Main |"""

count_words = lambda x, y: (len(x) - len(x.replace(y, ""))) // len(y)
print("High: Main count: ", count_words(high_part_string, "Main"))
print("High: Other count: ", count_words(high_part_string, "Other"))
print("High: Subordinate count: ", count_words(high_part_string, "Subordinate"))
print("Low: Main count: ", count_words(low_part_string, "Main"))
print("Low: Other count: ", count_words(low_part_string, "Other"))
print("Low: Subordinate count: ", count_words(low_part_string, "Subordinate"))
# Out:
# High: Main count:  14
# High: Other count:  13
# High: Subordinate count:  7
# Low: Main count:  48
# Low: Other count:  7
# Low: Subordinate count:  8

# %%
df_joined.sort_values(by='pvalue')
# Out:
#       freq_low  freq_high         pvalue
# pos
# .     0.061483   0.018757   0.000000e+00
# NNP   0.047776   0.083841  1.138731e-167
# PRP   0.041962   0.025034   2.701730e-74
# :     0.004751   0.013337   3.151964e-65
# POS   0.001269   0.005569   4.175198e-43
# (     0.001461   0.005606   4.516599e-39
# SYM   0.000516   0.003132   3.590124e-30
# ''    0.003335   0.007607   8.322323e-28
# JJ    0.074644   0.089323   1.509918e-24
# NN    0.197462   0.218409   4.896668e-23
# DT    0.081387   0.069347   1.711888e-18
# MD    0.012438   0.007968   7.153517e-18
# RB    0.038067   0.030740   9.569137e-15
# CD    0.027163   0.033089   3.551285e-11
# PRP$  0.014592   0.011237   9.941847e-09
# ,     0.019963   0.016296   1.194405e-07
# CC    0.029155   0.025382   8.346366e-06
# WRB   0.004367   0.003170   1.601774e-04
# JJS   0.000959   0.001641   3.321295e-04
# $     0.001712   0.002324   9.253839e-03
# FW    0.000398   0.000684   1.997037e-02
# VBD   0.023357   0.021603   2.308315e-02
# ...

# %%
plt.hist(cap_latters_low, bins=10, alpha=0.1)
plt.hist(cap_latters_high, bins=10, alpha=0.1)
# Out:
# (array([8.985e+03, 8.290e+02, 8.170e+02, 1.430e+02, 1.430e+02, 2.500e+01,
#         3.300e+01, 5.000e+00, 1.100e+01, 4.000e+00]),
#  array([ 0. ,  1.5,  3. ,  4.5,  6. ,  7.5,  9. , 10.5, 12. , 13.5, 15. ]),
#  <BarContainer object of 10 artists>)

# %%
np.mean(cap_latters_high)
# Out:
# np.float64(0.8127330604820373)

# %%
np.mean(cap_latters_low)
# Out:
# np.float64(0.6809708737864077)

# %%
plt.hist(idf_lows, alpha=0.1, density=True, label='low group')
plt.hist(idf_highs, alpha=0.1, density=True, label='high group')
plt.title("IDF between two groups ")
# Out:
# Text(0.5, 1.0, 'IDF between two groups ')

# %%
np.mean(idf_lows), np.mean(idf_highs)
# Out:
# (np.float64(5.960069864285023), np.float64(5.415825064707486))

# %%
prompt = f"""You need find pattern, which distinuguish two parts of texts: high and low.

Low part:
{'\n'.join(low_parts_list)}



High part:
{'\n'.join(high_parts_list)}
"""

# %%
df_joineds = []
for df_mean in df_means:
    df_joined = df_mean.set_index("token").join(
        df_mean.groupby("token").count()[['weight']].rename(columns={'weight': 'count'})
    )
    df_joined = df_joined.reset_index()
    df_joined['repet'] = get_repets(df_joined['token'].values.tolist())
    df_joined = df_joined.reset_index()
    df_joined['index_quantile'] = (pd.qcut(df_joined['index'], q=99).rank(pct=True) * 100).apply(int)
    df_joineds.append(df_joined)

# %%
data = pd.concat(df_joineds)

# %%
data['is_prob_small'] = data['prob'] < 0.1
data['is_prob_big'] = data['prob'] > 0.9

# %%
data.groupby('is_prob_small')[['weight', 'quantile']].mean()
# Out:
#                   weight  quantile
# is_prob_small
# False          54.138356  48.40065
# True           60.571572  57.19719

# %%
data.groupby('is_prob_big')[['weight', 'quantile']].mean()
# Out:
#                 weight   quantile
# is_prob_big
# False        56.449509  51.895142
# True         56.270805  49.864013

# %%
df_mean = visualize_text(texts[20], tokenizer, model)
print("-------------------------------")
df_mean = visualize_text(texts[24], tokenizer, model)
print("-------------------------------")
df_mean = visualize_text(texts[22], tokenizer, model)
print("-------------------------------")
df_mean = visualize_text(texts[23], tokenizer, model)
# Out:
# <p style="font-size:14px;"><span style="background-color: #C3C3FF"><bos></span> <span style="background-color: #D8D8FF">The</span> <span style="background-color: #F0F0FF"> incident</span> <span style="background-color: #F3F3FF"> happened</span> <span style="background-color: #DCDCFF"> in</span> <span style="background-color: #EEEEFF"> December</span> <span style="background-color: #E2E2FF"> when</span> <span style="background-color: #FFF2F2"> the</span> <span style="background-color: #EEEEFF"> </span> <span style="background-color: #D3D3FF">1</span> <span style="background-color: #E2E2FF">8</span> <span style="background-color: #C6C6FF">-</span> <span style="background-color: #E0E0FF">year</span> <span style="background-color: #C6C6FF">-</span> <span style="background-color: #FAFAFF">old</span> <span style="background-color: #FFFEFE"> man</span> <span style="background-color: #FFD3D3"> suffered</span> <span style="background-color: #F3F3FF"> what</span> <span style="background-color:
# ...

# %%
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split


data = pd.concat(df_joineds)
data['idf'] = data['token'].apply(lambda x: idf[x])
data['tfidf'] = data['idf'] * data['count'].apply(lambda x: np.log(x + 0.0001))
data['quantile_shift_1'] = data['quantile'].shift(1)
data['quantile_shift_minus_1'] = data['quantile'].shift(-1)
# data['pos_tag'] = [elem[1] for elem in pos_tag(data['token'].values.tolist())]#, tagset='universal')]
train, test = train_test_split(data)
# X = ['freq_token',  'count',  'repet', 'index_quantile', 'quantile_shift_1', 'quantile_shift_minus_1', 'pos_tag', 'dot_distance', 'len_text']
X = ['count', 'quantile_shift_1', 'quantile_shift_minus_1',  'dot_distance',  'repet', 'prob',  'len_text', 'index', 'index_quantile', 'idf', 'tfidf'] #'pos_tag',]
# X = ['count', 'dot_distance',  'repet', 'prob',  'len_text', 'index', 'index_quantile', 'idf', 'tfidf'] #'pos_tag',]
# y = 'quantile'
y = 'weight'
clf = CatBoostRegressor(n_estimators=1000, max_depth=6)
clf.fit(train[X], train[y], silent=True)#, cat_features=['pos_tag'])
print("test: ", np.sqrt(np.mean((clf.predict(test[X]) - test[y]) ** 2)))
print('train: ',  np.sqrt(np.mean((clf.predict(train[X]) - train[y]) ** 2)))
# Out:
# test:  15.766335315776503
# train:  14.74367589555977

# %%
15.766335315776503 / 21.628127473098395
# Out:
# 0.7289736633643881

# %%
np.sqrt(np.mean((test[y].fillna(0.0).median() - test[y].fillna(0.0)) ** 2))
# Out:
# np.float64(21.628127473098395)

# %%
sorted(zip(X, clf.get_feature_importance()), key=lambda x: x[1])
# Out:
# [('index_quantile', np.float64(1.4638029397757508)),
#  ('repet', np.float64(1.8523024570410456)),
#  ('count', np.float64(3.338099135378885)),
#  ('dot_distance', np.float64(3.7711909357401225)),
#  ('index', np.float64(3.8974992254267438)),
#  ('tfidf', np.float64(7.418080256418773)),
#  ('prob', np.float64(7.540056020055702)),
#  ('quantile_shift_1', np.float64(13.32967514861555)),
#  ('len_text', np.float64(13.782709590066395)),
#  ('quantile_shift_minus_1', np.float64(14.93851212522996)),
#  ('idf', np.float64(28.66807216625108))]

# %%
plt.scatter(data['idf'], data['quantile'], alpha=0.005)
plt.show()

# %%
plt.scatter(data['idf'], data['prob'], alpha=0.005)
plt.title("idf vs prob")
plt.show()

# %%
plt.scatter(data['idf'], data['quantile_shift_1'], alpha=0.005)
plt.show()

# %%
data['quantile_decade'] = data['quantile'].apply(lambda x: x // 10)

# %%
data['idf_decade'] = data['idf'].apply(lambda x: np.round(x, 1))

# %%
data.groupby('idf_decade')[['quantile']].mean().plot()
# Out:
# <Axes: xlabel='idf_decade'>

# %%
data.query("idf_decade > 8")
# Out:
#      index             token      weight   quantile  len_text          prob  \
# 15      15            spiral   70.915016  82.500000       495  7.391875e-05
# 18      18       accentuated   51.736496  57.000000       495  1.210202e-07
# 20      20        tangential   68.889008  82.000000       495  4.521684e-05
# 21      21   discontinuities   54.159076  61.166667       495  5.820503e-03
# 31      31   discontinuities   58.507265  69.000000       495  1.691102e-02
# ..     ...               ...         ...        ...       ...           ...
# 39      39             Osaka   96.788197  91.000000       117  4.640409e-02
# 46      46              Hons  176.715454  99.000000       117  9.734063e-01
# 72      72             Osaka   93.564064  93.000000       117  6.359542e-02
# 80      80             Osaka   91.722683  91.500000       117  1.656136e-01
# 110    110             Osaka  125.740883  95.000000       117  5.083727e-01
#
# ...

# %%
data.groupby('quantile_decade')[['idf']].mean().plot()
# Out:
# <Axes: xlabel='quantile_decade'>

# %%
import shap


explainer = shap.Explainer(clf.predict, test[X])
shap_values = explainer(test[X].iloc[:1000])
shap.plots.beeswarm(shap_values)
# Out:
# PermutationExplainer explainer: 1001it [01:35,  9.39it/s]

# %%
data.groupby('index_quantile')[['weight', 'quantile']].mean().plot()
# Out:
# <Axes: xlabel='index_quantile'>

# %%
data.groupby('index_quantile')[['quantile']].mean().plot()
# Out:
# <Axes: xlabel='index_quantile'>

# %%
shap.plots.heatmap(shap_values[:1000])
# Out:
# <Axes: xlabel='Instances'>

# %%
shap.plots.heatmap(shap_values[:1000])
# Out:
# <Axes: xlabel='Instances'>

# %%
df_groups = []
df_bigs = []
df_frs = []
for df_joined in df_joineds:
    df_joined['is_prob_small'] = df_joined['prob'] < 0.1
    df_joined['is_prob_big'] = df_joined['prob'] > 0.9

    df_joined['is_first_rep'] = df_joined['repet'] == 1

    df_frs.append(df_joined.query("count > 1").groupby("is_first_rep")[['weight', 'quantile']].mean())
    df_groups.append(
        df_joined.groupby('is_prob_small')[['weight', 'quantile']].mean()
    )
    df_bigs.append(
        df_joined.groupby('is_prob_big')[['weight', 'quantile']].mean()
    )

# %%
df_groups = []
df_bigs = []
df_frs = []
for df_joined in df_joineds:
    df_joined['is_prob_small'] = df_joined['prob'] < 0.1
    df_joined['is_prob_big'] = df_joined['prob'] > 0.9

    df_joined['is_first_rep'] = df_joined['repet'] == 1

    df_frs.append(df_joined.query("count > 1").groupby("is_first_rep")[['weight', 'quantile']].mean())
    df_groups.append(
        df_joined.groupby('is_prob_small')[['weight', 'quantile']].mean()
    )
    df_bigs.append(
        df_joined.groupby('is_prob_big')[['weight', 'quantile']].mean()
    )

# %%
plt.hist(pd.concat(df_frs)[['quantile']].sort_index().iloc[:500], alpha=0.2, label='not first repetition')
plt.hist(pd.concat(df_frs)[['quantile']].sort_index().iloc[500:], alpha=0.2, label='first repetition')

plt.legend()
plt.title("quantile weight in count > 1, first repetitiono")
# Out:
# Text(0.5, 1.0, 'quantile weight in count > 1, first repetitiono')

# %%
plt.hist(pd.concat(df_frs)[['weight']].sort_index().iloc[:500], alpha=0.2)
plt.hist(pd.concat(df_frs)[['weight']].sort_index().iloc[500:], alpha=0.2)
# Out:
# (array([ 35., 125., 161., 114.,  41.,  14.,   6.,   2.,   1.,   1.]),
#  array([ 44.66468993,  50.48528339,  56.30587685,  62.12647032,
#          67.94706378,  73.76765724,  79.5882507 ,  85.40884416,
#          91.22943762,  97.05003108, 102.87062454]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(pd.concat(df_groups)[['quantile']].sort_index().iloc[:500], alpha=0.2)
plt.hist(pd.concat(df_groups)[['quantile']].sort_index().iloc[500:], alpha=0.2)
# Out:
# (array([ 16.,  76., 153., 149.,  66.,  26.,  10.,   1.,   1.,   2.]),
#  array([48.04166667, 51.01280864, 53.98395062, 56.95509259, 59.92623457,
#         62.89737654, 65.86851852, 68.83966049, 71.81080247, 74.78194444,
#         77.75308642]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(pd.concat(df_groups)[['quantile']].sort_index().iloc[:500], alpha=0.2, label='not small probability')
plt.hist(pd.concat(df_groups)[['quantile']].sort_index().iloc[500:], alpha=0.2, label='small probability')
plt.legend()
plt.title("quantile weight in small probability")
# Out:
# Text(0.5, 1.0, 'quantile weight in small probability')

# %%
plt.hist(pd.concat(df_groups)[['weight']].sort_index().iloc[:500], alpha=0.2)
plt.hist(pd.concat(df_groups)[['weight']].sort_index().iloc[500:], alpha=0.2)
# Out:
# (array([ 32., 133., 165., 112.,  44.,   8.,   5.,   0.,   0.,   1.]),
#  array([ 46.39445139,  53.06393628,  59.73342117,  66.40290606,
#          73.07239095,  79.74187584,  86.41136073,  93.08084562,
#          99.75033051, 106.4198154 , 113.08930029]),
#  <BarContainer object of 10 artists>)

# %%
data.query("count > 1").groupby("is_first_rep")[['weight', 'quantile']].mean()
# Out:
#                  weight   quantile
# is_first_rep
# False         51.594968  45.454338
# True          58.142798  54.103240

# %%
data[['index', 'weight']].corr('spearman')
# Out:
#            index    weight
# index   1.000000 -0.230249
# weight -0.230249  1.000000

# %%
data.groupby('is_first_repet')
