# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import pickle
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import networkx as nx
import scipy.stats as ss
import pandas as pd
import numpy as np

from phd_qwen_CUDA_clean import get_phd, load_roberta_model, load_qwen_model, get_embeds, preprocess_text
from lexicalrichness import LexicalRichness

from collections import Counter, defaultdict
from tqdm import tqdm
from phd_scale import get_prompt, set_all_seeds, load_qwen_model, get_embeds, get_answer,\
                      get_stats, get_embeds_tsne, get_mst_edge_lengths, calculate_df_edges
from phd_qwen_CUDA_clean import preprocess_text, pairwise_distances


set_all_seeds(42)
sns.set_style("darkgrid")

# %%
def get_len_tokens(tokenizer, text):
    return len(tokenizer.tokenize(text))


token = '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'
tokenizer, model = load_qwen_model("google/gemma-2-2b-it", device='cuda:2', token=token)
df_en = pd.read_json("../PHD_experiments/notebooks/PHD_another/data/dev_intrinc_dimensions_roberta_gemma_qwen_phd__mle_twonn_tle.json")
df_en['gemini_tokenizer_len'] = df_en['text'].apply(lambda x: get_len_tokens(tokenizer, preprocess_text(x)))
# df_en = df_en.query("gemini_tokenizer_len < 256")
text = df_en['text'].values.tolist()[1]
texts = df_en['text'].values.tolist()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Модель загружена на: cuda:2

# %%
from collections import Counter


def get_prompt(
    text,
    tokenizer,
    model,
    limit=None
):
    if limit:
        text = ''.join(tokenizer.tokenize(text)[:limit]).replace('▁', ' ')
    embeds, tokens = get_embeds_tsne(text, tokenizer, model, returns_tokenized=True, reducer_type='none')
    mst_lengths = get_mst_edge_lengths(embeds, return_matrix=True)
    df_edges = calculate_df_edges(tokens, mst_lengths)
    df_edges['quantile'] = (pd.qcut(df_edges['weight'], q=100).rank(pct=True) * 100).apply(int)

    return df_edges, tokens


def get_repets(tokens):
    cnt = defaultdict(int)
    repets = []
    for token in tokens:
        cnt[token] += 1
        repets.append(cnt[token])

    return repets

# %%
acf1_list = []
acf2_list = []
acf3_list = []
for text in tqdm(texts[:100]):
    embeds, tokens = get_embeds(text, tokenizer, model,  returns_tokenized=True)
    mst_lengths = get_mst_edge_lengths(embeds, return_matrix=True)
    df_edges = calculate_df_edges(tokens, mst_lengths).iloc[1:, :]
    df_edges['quantile'] = (pd.qcut(df_edges['weight'], q=99, duplicates='drop').rank(pct=True) * 100).apply(int)
    df_edges['quantile_dec'] = (pd.qcut(df_edges['weight'], q=9, duplicates='drop').rank(pct=True) * 10).apply(int)
    df_edges['quantile_half'] = (pd.qcut(df_edges['weight'], q=2, duplicates='drop').rank(pct=True) * 10).apply(int)
    acf1_list.append(pd.concat([df_edges['quantile'], df_edges['quantile'].shift(1).fillna(0)], axis=1).corr('spearman').iloc[0, 1])
    acf2_list.append(pd.concat([df_edges['quantile_dec'], df_edges['quantile_dec'].shift(1).fillna(0)], axis=1).corr('spearman').iloc[0, 1])
    acf3_list.append(pd.concat([df_edges['quantile_half'], df_edges['quantile_half'].shift(1).fillna(0)], axis=1).corr('spearman').iloc[0, 1])
# Out:
# 100%|██████████| 100/100 [00:31<00:00,  3.15it/s]

# %%
plt.s

# %%
plt.boxplot(acf3_list)
plt.show()

# %%
plt.boxplot(acf2_list)
plt.show()

# %%
df_edges['quantile_half'].plot()
plt.show()

# %%
row_indices = df_edges.query("token_first == '.'")['row'].values.tolist()
col_indices = df_edges.query("token_first == '.'")['col'].values.tolist()

dot_indices = list(set(row_indices).union(col_indices))

# %%
text
# Out:
# "Bring a coffeemaker into your room, if you have one. The coffee will help you stay awake and bringing it in your room will decrease noise level. You may also drink tea, soda, energy drinks, or any other caffeinated beverage.\n\n\nBear in mind that coffee won't keep you awake forever.\nDon't overload on coffee, or you will become shaky and frazzled. Drink as much as you need to stay awake.;\n, The shock of the cold water may help wake you up. Also consider using a cold, wet washcloth, or taking a cold shower.\n\n, Anything you can do to elevate your heart-rate can keep you energized for a little while. Do jumping jacks, jump on your bed, or even jog in place for a few minutes. Small bursts of physical activity when you get tired can help you stay awake.\n\n, Your mind associates your bed with sleep. If you lay in your bed, you will trigger the process of falling asleep, and you may find it more difficult to keep your eyes open.\n\n, Shut your eyes and set your alarm for about twenty minutes. When you wake up, you'll likely feel rested and re-energized. Be careful not to sleep much longer than 20 minutes, however, or you may wake up groggy!\n\n\nWhen you awake from your power nap, get up immediately. Don't lie in bed, and don't hit the snooze button. The longer you stretch the nap, the more likely you are to slip into sleep.\n\n, Keep the lights on and don't keep staring at only one spot. Look at bright colors, or stare at your computer screen.\n\n, Try to eat protein-rich foods such as sandwiches, nuts, and dairy products. Sugary foods may make you feel awake for a little while, but they can eventually make you feel drowsy as you crash off the sugar high."

# %%
df_edges['quantile'].plot()
for dot_index in dot_indices:
    plt.axvline(dot_index + 1, color='red')
plt.show()

# %%
df_edges['quantile'].plot()
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plt.boxplot(acf1_list)
plt.show()

# %%
plot_pacf(df_edges['weight'].iloc[100:])

# %%
plot_acf(df_edges['quantile'].iloc[100:])

# %%
plot_acf(df_edges['quantile'].iloc[:100])

# %%
pd.concat(col_dfs, axis=1).T.mean().sort_index().plot()
print(pd.concat(col_dfs, axis=1).T.mean().sort_index().reset_index().corr('spearman').iloc[0, 1])
plt.show()
# Out:
# -0.5900058241118229

# %%
pd.concat(weight_list, axis=1).T.mean().sort_index().plot()
print(pd.concat(weight_list, axis=1).T.mean().sort_index().reset_index().corr('spearman').iloc[0, 1])
plt.show()
# Out:
# -0.785055329062318

# %%
pd.concat(mean_dfs, axis=1).T.mean().sort_index().plot()
print(pd.concat(mean_dfs, axis=1).T.mean().sort_index().reset_index().corr('spearman').iloc[0, 1])
plt.show()
# Out:
# -0.7264414676761793

# %%
pd.concat(col_dfs, axis=1).T.mean().sort_index().plot()
print(pd.concat(col_dfs, axis=1).T.mean().sort_index().reset_index().corr('spearman').iloc[0, 1])
plt.show()
# Out:
# -0.5900058241118229

# %%
## calculating number of disorders:

def get_disorders(array):
    disorders = 0
    for i in range(len(array)):
        for j in range(i):
            if array[i] < array[j]:
                disorders += 1

    return 2 * disorders / (len(array) * (len(array) - 1))

# %%
df_edges['diff'].hist(bins=20)
plt.show()

# %%
## Задача проинтерпретировать большие листья.
from tqdm import tqdm


mean_lst = []
count_lst = []
weight_lst = []
mean_diff_lst = []
disorders_lst = []
relative_twins_lst = []

for text in tqdm(texts[:100]):
    embeds, tokens = get_embeds(text, tokenizer, model,  returns_tokenized=True)
    mst_lengths = get_mst_edge_lengths(embeds, return_matrix=True)
    df_edges = calculate_df_edges(tokens, mst_lengths)
    df_edges['quantile'] = (pd.qcut(df_edges['weight'], q=99).rank(pct=True) * 100).apply(int)#
    # df_edges['row_new'] = df_edges['row'].astype(str) + '_' + df_edges['token_first'].str[:6]
    # df_edges['col_new'] = df_edges['col'].astype(str) + '_' + df_edges['token_second'].str[:6]
    G = nx.Graph()
    vertices = list(set(df_edges['row'].values.tolist() + df_edges['col'].values.tolist()))
    edges = df_edges[['row', 'col', 'weight']].drop_duplicates().values.tolist()
    # weights = np.array(edges)[:, ]
    # edges = np.array(edges)[:, [0, 1]]
    G.add_nodes_from(vertices)
    G.add_weighted_edges_from(edges)
    df_degrees = pd.DataFrame(G.degree(), columns=['vertex_id', 'degree'])
    df_degrees = df_degrees.set_index("vertex_id")
    df_edges = df_edges.set_index("row").join(df_degrees, rsuffix='_left').rename(columns={'degree':'degree_left'})
    df_edges = df_edges.reset_index().rename(
        columns={'index': 'row'}
    ).set_index("col").join(df_degrees).rename(columns={'degree': 'degree_right'})
    df_edges = df_edges.reset_index("col")
    df_edges['is_leaf'] = (df_edges['degree_left'] == 1) | (df_edges['degree_right'] == 1)
    df_edges['is_big_leaf'] = (df_edges['is_leaf']).values & (df_edges['quantile'] > 80).values
    
    df_degrees['repets'] = get_repets(tokens)
    df_edges = df_edges.set_index("row").join(df_degrees[['repets']], rsuffix='_left').rename(columns={'repets':'repets_left'})
    df_edges = df_edges.reset_index().rename(
        columns={'index': 'row'}
    ).set_index("col").join(df_degrees[['repets']]).rename(columns={'repets': 'repets_right'})
    df_edges = df_edges.reset_index("col")
    df_edges['is_sentence_start'] = (df_edges['row'] == 0).values | (df_edges['token_first'].str.contains(r'.', regex=False).shift(1).fillna(False)).values
    df_edges['repets_sum'] = df_edges['repets_left'] + df_edges['repets_right']
    df_edges['first_repet'] = (df_edges['repets_left'] == 1).values | (df_edges['repets_right'] == 1).values
    df_edges['is_tween_edge'] = df_edges['token_first'] == df_edges['token_second'] 
    df_edges['diff'] = df_edges['col'] - df_edges['row']
    relative_twins_lst.append(df_edges.groupby("is_big_leaf")[['is_tween_edge']].mean())
    mean_diff_by_twins = df_edges.groupby(['is_tween_edge'])[['diff']].mean()
    df_mean = df_edges.groupby(['first_repet', 'is_sentence_start', 'is_tween_edge'])[['is_big_leaf']].mean()
    df_count = df_edges.groupby(['first_repet', 'is_sentence_start', 'is_tween_edge'])[['is_big_leaf']].count()
    df_weight = df_edges.groupby(['first_repet', 'is_sentence_start', 'is_tween_edge'])[['quantile']].mean()

    
    relative_diff_lst.append(mean_diff_by_twins)
    mean_lst.append(df_mean)
    count_lst.append(df_count)
    weight_lst.append(df_weight)
    mean_diff_lst.append((df_edges['col'] - df_edges['row']).median())
    disorders_lst.append(get_disorders(df_edges['col']))
# Out:
# 100%|██████████| 100/100 [00:40<00:00,  2.49it/s]

# %%
pd.concat(relative_twins_lst).reset_index().groupby("is_big_leaf")[['is_tween_edge']].mean()
# Out:
#              is_tween_edge
# is_big_leaf
# False             0.261086
# True              0.181153

# %%
df_head = df_en.head(100)

df_head['med_diff'] = mean_diff_lst
df_head['disorders'] = disorders_lst

# %%
df_head['rel_med_diff'] = df_head['med_diff']  / df_head['gemini_tokenizer_len']
df_head['inverse_rel_med_diff'] = 1 / df_head['rel_med_diff']

# %%
df_head['MTLD'] = df_head['text'].apply(mtld_calculate2)
df_head['Summer'] = df_head['text'].apply(summer_calculate2)

# %%
plt.scatter(df_head['MTLD'] , 1 / df_head['rel_med_diff'])
plt.show()

# %%
plt.scatter(df_head['phd_gemma'], df_head['rel_med_diff'])
plt.show()

# %%
df_head[['inverse_rel_med_diff', 'MTLD']].corr('spearman')

# %%
df_head[['inverse_rel_med_diff', 'phd_qwen']].corr('spearman')

# %%
ttr_list = []

for text in texts[:1000]:
    tokens = tokenizer.tokenize(text)
    ttr_list.append(len(set(tokens)) / len(tokens))

# %%
df_head['ttr'] = ttr_list

# %%
df_head.query("6 < phd_roberta < 12")[[
    'phd_qwen',
    'med_diff',
    'gemini_tokenizer_len',
    'rel_med_diff',
    'phd_roberta',
    'phd_gemma',
    'ttr',
    'MTLD',
    'Summer',
    'disorders'
]].corr('spearman')

# %%
## Построить классификатор по предикту веса от всех признаков ранее и посмотреть что будет.

# %%
print(1)
# Out:
# 1

# %%
plt.figure(figsize=(14, 14))
pd.concat(weight_lst, axis=1).T.boxplot()
plt.show()

# %%
plt.figure(figsize=(12, 12))

pd.concat(mean_lst, axis=1).T.boxplot()

plt.show()

# %%
df_edges[['quantile', 'repets_left', 'repets_right', 'is_sentence_start', 'repets_sum', 'first_repet']].corr('spearman')
# Out:
#                    quantile  repets_left  repets_right  is_sentence_start  \
# quantile           1.000000     0.009165      0.015104          -0.029471
# repets_left        0.009165     1.000000      0.294949          -0.020337
# repets_right       0.015104     0.294949      1.000000           0.113215
# is_sentence_start -0.029471    -0.020337      0.113215           1.000000
# repets_sum         0.029751     0.761971      0.779684           0.059264
# first_repet        0.004298    -0.631124     -0.625520          -0.038894
#
#                    repets_sum  first_repet
# quantile             0.029751     0.004298
# repets_left          0.761971    -0.631124
# repets_right         0.779684    -0.625520
# is_sentence_start    0.059264    -0.038894
# repets_sum           1.000000    -0.574718
# first_repet         -0.574718     1.000000

# %%
df_edges[['repets_left', 'repets_right']].value_counts()
# Out:
# repets_left  repets_right
# 1            1               118
#              2                18
# 2            1                10
# 3            1                 7
# 1            3                 4
# 2            2                 3
#              3                 3
# 1            4                 2
# 3            4                 2
# 5            1                 2
# 4            5                 2
# 2            5                 2
# 4            1                 2
# 1            7                 1
#              5                 1
#              6                 1
# 3            6                 1
#              5                 1
# 2            4                 1
# 4            2                 1
# 5            2                 1
#              6                 1
# 6            1                 1
#              2                 1
# Name: count, dtype: int64

# %%
df_edges[['repets_left']].value_counts()
# Out:
# repets_left
# 1              145
# 2               19
# 3               11
# 4                5
# 5                4
# 6                2
# Name: count, dtype: int64

# %%
df_edges['is_leaf'].value_counts()
# Out:
# is_leaf
# False    60
# True     40
# Name: count, dtype: int64

# %%
df_edges['is_big_leaf'].value_counts()
# Out:
# is_big_leaf
# False    91
# True      9
# Name: count, dtype: int64

# %%
df_edges.groupby("is_leaf")['quantile'].mean()
# Out:
# is_leaf
# False    49.583333
# True     51.700000
# Name: quantile, dtype: float64

# %%
df_edges['degree_sum'] = df_edges['degree_left'] + df_edges['degree_right']

# %%
 df_edges.groupby(['first_repet', 'is_sentence_start', 'is_tween_edge'])[['is_big_leaf']].mean()
# Out:
#                                              is_big_leaf
# first_repet is_sentence_start is_tween_edge
# False       False             False             0.000000
#                               True              0.000000
#             True              True              0.000000
# True        False             False             0.115385
#                               True              0.166667
#             True              False             0.250000
#                               True              0.000000

# %%
 df_edges.groupby(['first_repet', 'is_sentence_start'])[['is_big_leaf']].mean()
# Out:
#                                is_big_leaf
# first_repet is_sentence_start
# False       False                 0.000000
#             True                  0.000000
# True        False                 0.117284
#             True                  0.200000

# %%
df_edges.query("degree_left == 1")
# Out:
#     col  row      weight token_first  token_second  quantile  degree_left  \
# 0    87    0  116.190323       <bos>             '        97            1
# 1    39    1  140.826340           (             '        99            1
# 2     5    2   74.836319   Apologies   submissions        90            1
# 3     4    3   71.281609         for           two        85            1
# 7     7    6   41.724873           ,           but        17            1
# 11   16   11   55.691639          .)             ,        50            1
# 12   22   12   83.263626        Dear             s        92            1
# 13   15   13  126.378288       Power          cons        98            1
# 14   39   14  174.748474         Fal             '       100            1
# 17   42   17   68.651680         Hey          with        80            1
# 23   32   20   28.322208          It            It         3            1
# 28   24   23   55.269405          me             ,        47            1
# 30   65   27   59.720051         How           how        57            1
# 60   50   49   36.991158         way     sometimes        12            1
# 65   57   55   48.455360    thinking           you        25            1
# 70   64   61   52.631615       check           see        42            1
# 71   68   62   55.395084          in         doing        48            1
# 84   77   75   37.608723       great           you        15            1
# 90   84   83   67.056114          me          know        76            1
# 95   91   90   63.820457           I           can        66            1
# 97   95   92   45.097313          do           out        18            1
# 98   95   94   34.567699        help           out         7            1
#
#     degree_right  is_leaf  is_big_leaf  degree_sum
# 0              2     True         True           3
# 1              4     True         True           5
# 2              3     True         True           4
# 3              3     True         True           4
# 7              2     True        False           3
# 11             3     True        False           4
# 12             3     True         True           4
# 13             2     True         True           3
# 14             4     True         True           5
# 17             3     True        False           4
# 23             4     True        False           5
# 28             2     True        False           3
# 30             5     True        False           6
# 60             2     True        False           3
# 65             3     True        False           4
# 70             4     True        False           5
# 71             3     True        False           4
# 84             6     True        False           7
# 90             3     True        False           4
# 95             2     True        False           3
# 97             3     True        False           4
# 98             3     True        False           4

# %%
df_edges
# Out:
#     col  row      weight token_first  token_second  quantile  degree_left  \
# 0    87    0  116.190323       <bos>             '        97            1
# 1    39    1  140.826340           (             '        99            1
# 2     5    2   74.836319   Apologies   submissions        90            1
# 3     4    3   71.281609         for           two        85            1
# 4     5    4   70.287796         two   submissions        84            3
# ..  ...  ...         ...         ...           ...       ...          ...
# 95   91   90   63.820457           I           can        66            1
# 96   93   91   59.544003         can            to        56            2
# 97   95   92   45.097313          do           out        18            1
# 98   95   94   34.567699        help           out         7            1
# 99   99   98   54.278561        care             ,        45            2
#
#     degree_right  is_leaf  is_big_leaf  degree_sum  repets_left  repets_left  \
# 0              2     True         True           3            1            4
# 1              4     True         True           5            1            3
# 2              3     True         True           4            1            1
# 3              3     True         True           4            1            1
# 4              3    False        False           6            1            1
# ..           ...      ...          ...         ...          ...          ...
# 95             2     True        False           3            4            1
# 96             2    False        False           4            1            3
# 97             3     True        False           4            1            1
# 98             3     True        False           4            1            1
# 99             2    False        False           4            1            5
#
#     repets_left  repets_right
# 0             1             4
# 1             1             3
# 2             1             1
# 3             1             1
# 4             1             1
# ..          ...           ...
# 95            4             1
# 96            1             3
# 97            1             1
# 98            1             1
# 99            1             5
#
# [100 rows x 15 columns]
